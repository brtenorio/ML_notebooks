# %%
# %%sql
# SHOW CATALOGS;
# -- Usamos catalogo workspace
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>catalog</th></tr></thead><tbody><tr><td>samples</td></tr><tr><td>system</td></tr><tr><td>workspace</td></tr></tbody></table></div>
# DataFrame[catalog: string]

# %%
# %%sql
# SHOW VOLUMES;
# --criamos volumes em default
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>volume_name</th></tr></thead><tbody></tbody></table></div>
# DataFrame[database: string, volume_name: string]

# %%
# %%sql
# CREATE VOLUME IF NOT EXISTS workspace.default.dados;
# --o caminho do volume:
# --/Volumes/workspace/default/dados
# --agora podemos ir catalog e import todos os dados para este volume

# %%
# %%sql
# SHOW VOLUMES;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>volume_name</th></tr></thead><tbody><tr><td>default</td><td>dados</td></tr></tbody></table></div>
# DataFrame[database: string, volume_name: string]

# %%
#importar dados definindo schema
#vamos deixar a data como string de propósito
from pyspark.sql.types import *
arqschema = "id INT, nome STRING, status STRING, cidade STRING, vendas INT, data STRING"
#o caminho do arquivo no volume
despachantes = spark.read.csv("/Volumes/workspace/default/dados/despachantes.csv", header=False, schema=arqschema)
despachantes.show()
# Out:
# +---+-------------------+------+-------------+------+----------+
# | id|               nome|status|       cidade|vendas|      data|
# +---+-------------------+------+-------------+------+----------+
# |  1|   Carminda Pestana| Ativo|  Santa Maria|    23|2020-08-11|
# |  2|    Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
# |  3|   Emídio Dornelles| Ativo| Porto Alegre|    34|2020-02-05|
# |  4|Felisbela Dornelles| Ativo| Porto Alegre|    36|2020-02-05|
# |  5|     Graça Ornellas| Ativo| Porto Alegre|    12|2020-02-05|
# |  6|   Matilde Rebouças| Ativo| Porto Alegre|    22|2019-01-05|
# |  7|    Noêmia   Orriça| Ativo|  Santa Maria|    45|2019-10-05|
# |  8|      Roque Vásquez| Ativo| Porto Alegre|    65|2020-03-05|
# |  9|      Uriel Queiroz| Ativo| Porto Alegre|    54|2018-05-05|
# | 10|   Viviana Sequeira| Ativo| Porto Alegre|     0|2020-09-05|
# +---+-------------------+------+-------------+------+----------+

# %%
#outro exemplo, inferindo schema, usando load e informado tipo
desp_autoschema = spark.read.load("/Volumes/workspace/default/dados/despachantes.csv",
                     format="csv", sep=",", inferSchema=True, header=False)
desp_autoschema.show()
# Out:
# +---+-------------------+-----+-------------+---+----------+
# |_c0|                _c1|  _c2|          _c3|_c4|       _c5|
# +---+-------------------+-----+-------------+---+----------+
# |  1|   Carminda Pestana|Ativo|  Santa Maria| 23|2020-08-11|
# |  2|    Deolinda Vilela|Ativo|Novo Hamburgo| 34|2020-03-05|
# |  3|   Emídio Dornelles|Ativo| Porto Alegre| 34|2020-02-05|
# |  4|Felisbela Dornelles|Ativo| Porto Alegre| 36|2020-02-05|
# |  5|     Graça Ornellas|Ativo| Porto Alegre| 12|2020-02-05|
# |  6|   Matilde Rebouças|Ativo| Porto Alegre| 22|2019-01-05|
# |  7|    Noêmia   Orriça|Ativo|  Santa Maria| 45|2019-10-05|
# |  8|      Roque Vásquez|Ativo| Porto Alegre| 65|2020-03-05|
# |  9|      Uriel Queiroz|Ativo| Porto Alegre| 54|2018-05-05|
# | 10|   Viviana Sequeira|Ativo| Porto Alegre|  0|2020-09-05|
# +---+-------------------+-----+-------------+---+----------+

# %%
#comparando os schemas, outra forma
desp_autoschema.printSchema()
despachantes.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: integer (nullable = true)
#  |-- _c5: date (nullable = true)
#
# root
#  |-- id: integer (nullable = true)
#  |-- nome: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- cidade: string (nullable = true)
#  |-- vendas: integer (nullable = true)
#  |-- data: string (nullable = true)

# %%
from pyspark.sql import functions as Func
#condição lógica com where
despachantes.select("id","nome","vendas").where(Func.col("vendas") > 20).show()
#& para and, | para or, e ~ para not
despachantes.select("id","nome","vendas").where((Func.col("vendas") > 20) & (Func.col("vendas") < 40)).show()
# Out:
# +---+-------------------+------+
# | id|               nome|vendas|
# +---+-------------------+------+
# |  1|   Carminda Pestana|    23|
# |  2|    Deolinda Vilela|    34|
# |  3|   Emídio Dornelles|    34|
# |  4|Felisbela Dornelles|    36|
# |  6|   Matilde Rebouças|    22|
# |  7|    Noêmia   Orriça|    45|
# |  8|      Roque Vásquez|    65|
# |  9|      Uriel Queiroz|    54|
# +---+-------------------+------+
#
# +---+-------------------+------+
# | id|               nome|vendas|
# +---+-------------------+------+
# |  1|   Carminda Pestana|    23|
# |  2|    Deolinda Vilela|    34|
# |  3|   Emídio Dornelles|    34|
# |  4|Felisbela Dornelles|    36|
# |  6|   Matilde Rebouças|    22|
# +---+-------------------+------+

# %%
despachantes["id","nome","vendas"].where(despachantes["vendas"] > 20).show()

despachantes["id","nome","vendas"].where((despachantes["vendas"] > 20) & (despachantes["vendas"] < 40)).show()

despachantes["id","nome","vendas"].where((despachantes["vendas"] > 20) & \
    (despachantes["vendas"] < 40) & (despachantes["nome"] != "Matilde Rebouças")).show()
# Out:
# +---+-------------------+------+
# | id|               nome|vendas|
# +---+-------------------+------+
# |  1|   Carminda Pestana|    23|
# |  2|    Deolinda Vilela|    34|
# |  3|   Emídio Dornelles|    34|
# |  4|Felisbela Dornelles|    36|
# |  6|   Matilde Rebouças|    22|
# |  7|    Noêmia   Orriça|    45|
# |  8|      Roque Vásquez|    65|
# |  9|      Uriel Queiroz|    54|
# +---+-------------------+------+
#
# +---+-------------------+------+
# | id|               nome|vendas|
# +---+-------------------+------+
# |  1|   Carminda Pestana|    23|
# |  2|    Deolinda Vilela|    34|
# |  3|   Emídio Dornelles|    34|
# |  4|Felisbela Dornelles|    36|
# |  6|   Matilde Rebouças|    22|
# +---+-------------------+------+
#
# +---+-------------------+------+
# | id|               nome|vendas|
# +---+-------------------+------+
# |  1|   Carminda Pestana|    23|
# |  2|    Deolinda Vilela|    34|
# |  3|   Emídio Dornelles|    34|
# |  4|Felisbela Dornelles|    36|
# ...

# %%
#renomear coluna
novodf = despachantes.withColumnRenamed("nome","nomes")
novodf.columns
# Out:
# ['id', 'nomes', 'status', 'cidade', 'vendas', 'data']

# %%
from pyspark.sql.functions import *
#coluna data está como string, vamos transformar em data
despachantes2 = despachantes.withColumn("data2", to_timestamp(Func.col("data"),"yyyy-MM-dd"))
despachantes2.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- nome: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- cidade: string (nullable = true)
#  |-- vendas: integer (nullable = true)
#  |-- data: string (nullable = true)
#  |-- data2: timestamp (nullable = true)

# %%
from pyspark.sql.functions import to_date, date_format
despachantes2 = despachantes.withColumn("data2", to_date("data","yyyy-M-d")
                                        )

despachantes2.show()

despachantes2.printSchema()
# Out:
# +---+-------------------+------+-------------+------+----------+----------+
# | id|               nome|status|       cidade|vendas|      data|     data2|
# +---+-------------------+------+-------------+------+----------+----------+
# |  1|   Carminda Pestana| Ativo|  Santa Maria|    23|2020-08-11|2020-08-11|
# |  2|    Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|2020-03-05|
# |  3|   Emídio Dornelles| Ativo| Porto Alegre|    34|2020-02-05|2020-02-05|
# |  4|Felisbela Dornelles| Ativo| Porto Alegre|    36|2020-02-05|2020-02-05|
# |  5|     Graça Ornellas| Ativo| Porto Alegre|    12|2020-02-05|2020-02-05|
# |  6|   Matilde Rebouças| Ativo| Porto Alegre|    22|2019-01-05|2019-01-05|
# |  7|    Noêmia   Orriça| Ativo|  Santa Maria|    45|2019-10-05|2019-10-05|
# |  8|      Roque Vásquez| Ativo| Porto Alegre|    65|2020-03-05|2020-03-05|
# |  9|      Uriel Queiroz| Ativo| Porto Alegre|    54|2018-05-05|2018-05-05|
# ...

# %%
from pyspark.sql.functions import to_date, date_format
despachantes3 = despachantes.withColumn("data2", date_format(to_date("data","yyyy-M-d"), "dd/MM/yyyy") 
                                        )
despachantes3.show()

despachantes3.printSchema()
# Out:
# +---+-------------------+------+-------------+------+----------+----------+
# | id|               nome|status|       cidade|vendas|      data|     data2|
# +---+-------------------+------+-------------+------+----------+----------+
# |  1|   Carminda Pestana| Ativo|  Santa Maria|    23|2020-08-11|11/08/2020|
# |  2|    Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|05/03/2020|
# |  3|   Emídio Dornelles| Ativo| Porto Alegre|    34|2020-02-05|05/02/2020|
# |  4|Felisbela Dornelles| Ativo| Porto Alegre|    36|2020-02-05|05/02/2020|
# |  5|     Graça Ornellas| Ativo| Porto Alegre|    12|2020-02-05|05/02/2020|
# |  6|   Matilde Rebouças| Ativo| Porto Alegre|    22|2019-01-05|05/01/2019|
# |  7|    Noêmia   Orriça| Ativo|  Santa Maria|    45|2019-10-05|05/10/2019|
# |  8|      Roque Vásquez| Ativo| Porto Alegre|    65|2020-03-05|05/03/2020|
# |  9|      Uriel Queiroz| Ativo| Porto Alegre|    54|2018-05-05|05/05/2018|
# ...

# %%
#operações sobre datas
despachantes2.select(year("data")).show()
despachantes2.select(year("data")).distinct().show()
despachantes2.select("nome",year("data")).orderBy("nome").show()
despachantes2.select("data").groupBy(year("data")).count().show()
despachantes2.select(Func.sum("vendas")).show()
# Out:
# +----------+
# |year(data)|
# +----------+
# |      2020|
# |      2020|
# |      2020|
# |      2020|
# |      2020|
# |      2019|
# |      2019|
# |      2020|
# |      2018|
# |      2020|
# +----------+
#
# +----------+
# |year(data)|
# +----------+
# |      2018|
# |      2019|
# |      2020|
# +----------+
#
# +-------------------+----------+
# |               nome|year(data)|
# +-------------------+----------+
# |   Carminda Pestana|      2020|
# |    Deolinda Vilela|      2020|
# |   Emídio Dornelles|      2020|
# |Felisbela Dornelles|      2020|
# |     Graça Ornellas|      2020|
# |   Matilde Rebouças|      2019|
# |    Noêmia   Orriça|      2019|
# |      Roque Vásquez|      2020|
# |      Uriel Queiroz|      2018|
# |   Viviana Sequeira|      2020|
# +-------------------+----------+
#
# +----------+-----+
# |year(data)|count|
# +----------+-----+
# |      2018|    1|
# |      2019|    2|
# |      2020|    7|
# +----------+-----+
#
# +-----------+
# |sum(vendas)|
# ...

# %%
despachantes2.agg({'vendas': 'sum'}).show()
# Out:
# +-----------+
# |sum(vendas)|
# +-----------+
# |        325|
# +-----------+

# %%
# salvar tipos, são diretórios
despachantes.write.format("parquet").save("/Volumes/workspace/default/dados/dfimportparquet")
despachantes.write.format("csv").save("/Volumes/workspace/default/dados/dfimportcsv")
despachantes.write.format("json").save("/Volumes/workspace/default/dados/dfimportjson")
despachantes.write.format("orc").save("/Volumes/workspace/default/dados/dfimportorc")
# podemos confirmar os dados olhando no volume

# %%
#ler dados
par = spark.read.format("parquet").load("/Volumes/workspace/default/dados/dfimportparquet/*.parquet")
par.show()
par.printSchema()
# Out:
# +---+-------------------+------+-------------+------+----------+
# | id|               nome|status|       cidade|vendas|      data|
# +---+-------------------+------+-------------+------+----------+
# |  1|   Carminda Pestana| Ativo|  Santa Maria|    23|2020-08-11|
# |  2|    Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
# |  3|   Emídio Dornelles| Ativo| Porto Alegre|    34|2020-02-05|
# |  4|Felisbela Dornelles| Ativo| Porto Alegre|    36|2020-02-05|
# |  5|     Graça Ornellas| Ativo| Porto Alegre|    12|2020-02-05|
# |  6|   Matilde Rebouças| Ativo| Porto Alegre|    22|2019-01-05|
# |  7|    Noêmia   Orriça| Ativo|  Santa Maria|    45|2019-10-05|
# |  8|      Roque Vásquez| Ativo| Porto Alegre|    65|2020-03-05|
# |  9|      Uriel Queiroz| Ativo| Porto Alegre|    54|2018-05-05|
# | 10|   Viviana Sequeira| Ativo| Porto Alegre|     0|2020-09-05|
# +---+-------------------+------+-------------+------+----------+
#
# root
#  |-- id: integer (nullable = true)
# ...

# %%
#formato tabular
despachantes.show(1)
# Out:
# +---+----------------+------+-----------+------+----------+
# | id|            nome|status|     cidade|vendas|      data|
# +---+----------------+------+-----------+------+----------+
# |  1|Carminda Pestana| Ativo|Santa Maria|    23|2020-08-11|
# +---+----------------+------+-----------+------+----------+
# only showing top 1 row

# %%
#formato de lista
despachantes.take(2) #/head/firt
# Out:
# [Row(id=1, nome='Carminda Pestana', status='Ativo', cidade='Santa Maria', vendas=23, data='2020-08-11'),
#  Row(id=2, nome='Deolinda Vilela', status='Ativo', cidade='Novo Hamburgo', vendas=34, data='2020-03-05')]

# %%
#retorna todos dados como uma lista
despachantes.collect()
# Out:
# [Row(id=1, nome='Carminda Pestana', status='Ativo', cidade='Santa Maria', vendas=23, data='2020-08-11'),
#  Row(id=2, nome='Deolinda Vilela', status='Ativo', cidade='Novo Hamburgo', vendas=34, data='2020-03-05'),
#  Row(id=3, nome='Emídio Dornelles', status='Ativo', cidade='Porto Alegre', vendas=34, data='2020-02-05'),
#  Row(id=4, nome='Felisbela Dornelles', status='Ativo', cidade='Porto Alegre', vendas=36, data='2020-02-05'),
#  Row(id=5, nome='Graça Ornellas', status='Ativo', cidade='Porto Alegre', vendas=12, data='2020-02-05'),
#  Row(id=6, nome='Matilde Rebouças', status='Ativo', cidade='Porto Alegre', vendas=22, data='2019-01-05'),
#  Row(id=7, nome='Noêmia   Orriça', status='Ativo', cidade='Santa Maria', vendas=45, data='2019-10-05'),
#  Row(id=8, nome='Roque Vásquez', status='Ativo', cidade='Porto Alegre', vendas=65, data='2020-03-05'),
#  Row(id=9, nome='Uriel Queiroz', status='Ativo', cidade='Porto Alegre', vendas=54, data='2018-05-05'),
# ...

# %%
#conta
despachantes.count()
# Out:
# 10

# %%
#transformações
#padrão crescente
despachantes.orderBy("vendas").show()
# Out:
# +---+-------------------+------+-------------+------+----------+
# | id|               nome|status|       cidade|vendas|      data|
# +---+-------------------+------+-------------+------+----------+
# | 10|   Viviana Sequeira| Ativo| Porto Alegre|     0|2020-09-05|
# |  5|     Graça Ornellas| Ativo| Porto Alegre|    12|2020-02-05|
# |  6|   Matilde Rebouças| Ativo| Porto Alegre|    22|2019-01-05|
# |  1|   Carminda Pestana| Ativo|  Santa Maria|    23|2020-08-11|
# |  3|   Emídio Dornelles| Ativo| Porto Alegre|    34|2020-02-05|
# |  2|    Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
# |  4|Felisbela Dornelles| Ativo| Porto Alegre|    36|2020-02-05|
# |  7|    Noêmia   Orriça| Ativo|  Santa Maria|    45|2019-10-05|
# |  9|      Uriel Queiroz| Ativo| Porto Alegre|    54|2018-05-05|
# |  8|      Roque Vásquez| Ativo| Porto Alegre|    65|2020-03-05|
# +---+-------------------+------+-------------+------+----------+

# %%
#decrescente
despachantes.orderBy(Func.col("vendas").desc()).show()
# Out:
# +---+-------------------+------+-------------+------+----------+
# | id|               nome|status|       cidade|vendas|      data|
# +---+-------------------+------+-------------+------+----------+
# |  8|      Roque Vásquez| Ativo| Porto Alegre|    65|2020-03-05|
# |  9|      Uriel Queiroz| Ativo| Porto Alegre|    54|2018-05-05|
# |  7|    Noêmia   Orriça| Ativo|  Santa Maria|    45|2019-10-05|
# |  4|Felisbela Dornelles| Ativo| Porto Alegre|    36|2020-02-05|
# |  2|    Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
# |  3|   Emídio Dornelles| Ativo| Porto Alegre|    34|2020-02-05|
# |  1|   Carminda Pestana| Ativo|  Santa Maria|    23|2020-08-11|
# |  6|   Matilde Rebouças| Ativo| Porto Alegre|    22|2019-01-05|
# |  5|     Graça Ornellas| Ativo| Porto Alegre|    12|2020-02-05|
# | 10|   Viviana Sequeira| Ativo| Porto Alegre|     0|2020-09-05|
# +---+-------------------+------+-------------+------+----------+

# %%
#decrescente alternativo
despachantes.orderBy("vendas", ascending=False).show()
# Out:
# +---+-------------------+------+-------------+------+----------+
# | id|               nome|status|       cidade|vendas|      data|
# +---+-------------------+------+-------------+------+----------+
# |  8|      Roque Vásquez| Ativo| Porto Alegre|    65|2020-03-05|
# |  9|      Uriel Queiroz| Ativo| Porto Alegre|    54|2018-05-05|
# |  7|    Noêmia   Orriça| Ativo|  Santa Maria|    45|2019-10-05|
# |  4|Felisbela Dornelles| Ativo| Porto Alegre|    36|2020-02-05|
# |  2|    Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
# |  3|   Emídio Dornelles| Ativo| Porto Alegre|    34|2020-02-05|
# |  1|   Carminda Pestana| Ativo|  Santa Maria|    23|2020-08-11|
# |  6|   Matilde Rebouças| Ativo| Porto Alegre|    22|2019-01-05|
# |  5|     Graça Ornellas| Ativo| Porto Alegre|    12|2020-02-05|
# | 10|   Viviana Sequeira| Ativo| Porto Alegre|     0|2020-09-05|
# +---+-------------------+------+-------------+------+----------+

# %%
#se quiser cidade dec e valor crescente
despachantes.orderBy(Func.col("cidade").desc(),Func.col("vendas")).show()
# Out:
# +---+-------------------+------+-------------+------+----------+
# | id|               nome|status|       cidade|vendas|      data|
# +---+-------------------+------+-------------+------+----------+
# |  1|   Carminda Pestana| Ativo|  Santa Maria|    23|2020-08-11|
# |  7|    Noêmia   Orriça| Ativo|  Santa Maria|    45|2019-10-05|
# | 10|   Viviana Sequeira| Ativo| Porto Alegre|     0|2020-09-05|
# |  5|     Graça Ornellas| Ativo| Porto Alegre|    12|2020-02-05|
# |  6|   Matilde Rebouças| Ativo| Porto Alegre|    22|2019-01-05|
# |  3|   Emídio Dornelles| Ativo| Porto Alegre|    34|2020-02-05|
# |  4|Felisbela Dornelles| Ativo| Porto Alegre|    36|2020-02-05|
# |  9|      Uriel Queiroz| Ativo| Porto Alegre|    54|2018-05-05|
# |  8|      Roque Vásquez| Ativo| Porto Alegre|    65|2020-03-05|
# |  2|    Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
# +---+-------------------+------+-------------+------+----------+

# %%
#se quiser cidade dec e valor crescente alternativo
despachantes.orderBy(["cidade","vendas"],ascending=[False,True]).show()
# Out:
# +---+-------------------+------+-------------+------+----------+
# | id|               nome|status|       cidade|vendas|      data|
# +---+-------------------+------+-------------+------+----------+
# |  1|   Carminda Pestana| Ativo|  Santa Maria|    23|2020-08-11|
# |  7|    Noêmia   Orriça| Ativo|  Santa Maria|    45|2019-10-05|
# | 10|   Viviana Sequeira| Ativo| Porto Alegre|     0|2020-09-05|
# |  5|     Graça Ornellas| Ativo| Porto Alegre|    12|2020-02-05|
# |  6|   Matilde Rebouças| Ativo| Porto Alegre|    22|2019-01-05|
# |  3|   Emídio Dornelles| Ativo| Porto Alegre|    34|2020-02-05|
# |  4|Felisbela Dornelles| Ativo| Porto Alegre|    36|2020-02-05|
# |  9|      Uriel Queiroz| Ativo| Porto Alegre|    54|2018-05-05|
# |  8|      Roque Vásquez| Ativo| Porto Alegre|    65|2020-03-05|
# |  2|    Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
# +---+-------------------+------+-------------+------+----------+

# %%
#agrupar dados
#ver vendas por cidade
despachantes.groupBy("cidade").agg(sum("vendas")).show()
# Out:
# +-------------+-----------+
# |       cidade|sum(vendas)|
# +-------------+-----------+
# |  Santa Maria|         68|
# | Porto Alegre|        223|
# |Novo Hamburgo|         34|
# +-------------+-----------+

# %%
#ordernar por vendas decrecente
from pyspark.sql import functions as F
despachantes.groupBy("cidade").agg(F.sum("vendas").alias("total_vendas")).orderBy(F.desc("total_vendas")).show()
# Out:
# +-------------+------------+
# |       cidade|total_vendas|
# +-------------+------------+
# | Porto Alegre|         223|
# |  Santa Maria|          68|
# |Novo Hamburgo|          34|
# +-------------+------------+

# %%
#filter
despachantes.filter(Func.col("nome") == "Deolinda Vilela").show()
# Out:
# +---+---------------+------+-------------+------+----------+
# | id|           nome|status|       cidade|vendas|      data|
# +---+---------------+------+-------------+------+----------+
# |  2|Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
# +---+---------------+------+-------------+------+----------+

# %%
despachantes[despachantes["nome"] == "Deolinda Vilela"].show()
# Out:
# +---+---------------+------+-------------+------+----------+
# | id|           nome|status|       cidade|vendas|      data|
# +---+---------------+------+-------------+------+----------+
# |  2|Deolinda Vilela| Ativo|Novo Hamburgo|    34|2020-03-05|
# +---+---------------+------+-------------+------+----------+

# %%
# Até agora era dataframe em memória, criamos tabela gerenciada e persistida e registrada no catalogo
# workspace/default/tables
despachantes.write.saveAsTable("Despachantes")
